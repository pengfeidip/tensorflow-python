# %%
import tensorflow as tf
import numpy as np
import Ipynb_importer
import myNet_infer_1
# Out:
# importing Jupyter notebook from myNet_infer_1.ipynb

# %%
BATCH_SIZE = 100

NUM_EPOCH = 30000 #迭代次数、
LEARNING_RATE = 0.01  # larning rate
def train_model(mnist):

    x = tf.placeholder(dtype=tf.float32, shape=[BATCH_SIZE, 28, 28, 1],name="input")
    y_predicted = myNet_infer_1.LeNet_inference(x)
    y_label = tf.placeholder(dtype=tf.float32, shape=[BATCH_SIZE, 10], name="label")

    """
    loss function and optimization 

    """
    #result = tf.multiply(y_predicted, 1, name="infer")
    loss_all = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_label, logits=y_predicted)
    loss = tf.reduce_mean(loss_all)
    train_op = tf.train.GradientDescentOptimizer(LEARNING_RATE).minimize(loss)
    
    """设置, tf最大占用显卡内存比例, 并让gpu自主增长所需要内存: 因为tf正常会自动占有所有内存"""
    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.7  # 程序最多只能占用指定gpu50%的显存
    config.gpu_options.allow_growth = True 
    
    loss_list = np.array([])
    import time
    saver = tf.train.Saver()
    with tf.Session(config = config) as sess:
        sess.run(tf.global_variables_initializer())
        start_all = time.time()
        
        for i in range(NUM_EPOCH):
            
            xs,ys = mnist.train.next_batch(batch_size=BATCH_SIZE) #batch gradient descent
            xs.shape = (BATCH_SIZE, 28, 28, 1) #reshape the input 

            _, loss_np = sess.run([train_op, loss], feed_dict={x:xs, y_label:ys})
            
            if i% 500 == 0:
                loss_list = np.append(loss_list,loss_np )
                end = time.time()
                print("iteration: {} / {};  loss is {}, learning rate is {} .....".format(i, NUM_EPOCH,loss_np, LEARNING_RATE))
                print( "共用时: ", end - start_all)
                saver.save(sess, "./model_param_1/model.ckpt",global_step = i)

        print("training is end")
        return

# %%
def read_date():
    from tensorflow.examples.tutorials.mnist import input_data
    mnist = input_data.read_data_sets('./input_data', one_hot=True, validation_size=500)
    return mnist

# %%
def main(argv = None):
    mnist = read_date()
    train_model(mnist)

if __name__ == "__main__":
    tf.app.run()
# Out:
# WARNING:tensorflow:From <ipython-input-3-c6b80f814b4d>:3: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./input_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./input_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ./input_data\t10k-images-idx3-ubyte.gz
# Extracting ./input_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# iteration: 0 / 30000;  loss is 23250.51953125, learning rate is 0.01 .....
# 共用时:  1.138368844985962
# iteration: 500 / 30000;  loss is 2.320319175720215, learning rate is 0.01 .....
# 共用时:  3.762155294418335
# iteration: 1000 / 30000;  loss is 2.2967114448547363, learning rate is 0.01 .....
# 共用时:  6.4456353187561035
# iteration: 1500 / 30000;  loss is 2.3011062145233154, learning rate is 0.01 .....
# 共用时:  9.092281341552734
# iteration: 2000 / 30000;  loss is 2.3263144493103027, learning rate is 0.01 .....
# 共用时:  11.808873891830444
# iteration: 2500 / 30000;  loss is 2.287505626678467, learning rate is 0.01 .....
# 共用时:  14.485494613647461
# iteration: 3000 / 30000;  loss is 2.300602436065674, learning rate is 0.01 .....
# 共用时:  17.335580348968506
# iteration: 3500 / 30000;  loss is 2.2940750122070312, learning rate is 0.01 .....
# 共用时:  19.96320390701294
# iteration: 4000 / 30000;  loss is 2.3272931575775146, learning rate is 0.01 .....
# 共用时:  22.563673973083496
# iteration: 4500 / 30000;  loss is 2.307060956954956, learning rate is 0.01 .....
# 共用时:  25.301973581314087
# iteration: 5000 / 30000;  loss is 2.3097376823425293, learning rate is 0.01 .....
# 共用时:  28.01699995994568
# iteration: 5500 / 30000;  loss is 2.3083715438842773, learning rate is 0.01 .....
# 共用时:  30.693679332733154
# iteration: 6000 / 30000;  loss is 2.3008127212524414, learning rate is 0.01 .....
# 共用时:  33.35436248779297
# iteration: 6500 / 30000;  loss is 2.3263962268829346, learning rate is 0.01 .....
# 共用时:  35.9470956325531
# iteration: 7000 / 30000;  loss is 2.280665636062622, learning rate is 0.01 .....
# 共用时:  38.66258955001831
# iteration: 7500 / 30000;  loss is 2.3121941089630127, learning rate is 0.01 .....
# 共用时:  41.35324692726135
# iteration: 8000 / 30000;  loss is 2.295247793197632, learning rate is 0.01 .....
# 共用时:  44.08745288848877
# iteration: 8500 / 30000;  loss is 2.3140926361083984, learning rate is 0.01 .....
# 共用时:  46.765448570251465
# iteration: 9000 / 30000;  loss is 2.295870542526245, learning rate is 0.01 .....
# 共用时:  49.49815535545349
# iteration: 9500 / 30000;  loss is 2.3166160583496094, learning rate is 0.01 .....
# 共用时:  52.05523490905762
# iteration: 10000 / 30000;  loss is 2.301088333129883, learning rate is 0.01 .....
# 共用时:  54.71603465080261
# iteration: 10500 / 30000;  loss is 2.293942451477051, learning rate is 0.01 .....
# 共用时:  57.40021347999573
# iteration: 11000 / 30000;  loss is 2.3203437328338623, learning rate is 0.01 .....
# 共用时:  60.304818868637085
# iteration: 11500 / 30000;  loss is 2.3178648948669434, learning rate is 0.01 .....
# 共用时:  62.951398849487305
# iteration: 12000 / 30000;  loss is 2.346648693084717, learning rate is 0.01 .....
# 共用时:  65.61927080154419
# iteration: 12500 / 30000;  loss is 2.329916000366211, learning rate is 0.01 .....
# 共用时:  68.39242315292358
# iteration: 13000 / 30000;  loss is 2.3210136890411377, learning rate is 0.01 .....
# 共用时:  70.97276425361633
# iteration: 13500 / 30000;  loss is 2.293321132659912, learning rate is 0.01 .....
# 共用时:  73.6421127319336
# iteration: 14000 / 30000;  loss is 2.301685333251953, learning rate is 0.01 .....
# 共用时:  76.35584664344788
# iteration: 14500 / 30000;  loss is 2.2910192012786865, learning rate is 0.01 .....
# 共用时:  79.04709148406982
# iteration: 15000 / 30000;  loss is 2.317119836807251, learning rate is 0.01 .....
# 共用时:  81.72530198097229
# iteration: 15500 / 30000;  loss is 2.30705189704895, learning rate is 0.01 .....
# 共用时:  84.46944427490234
# iteration: 16000 / 30000;  loss is 2.2965474128723145, learning rate is 0.01 .....
# 共用时:  87.08938550949097
# iteration: 16500 / 30000;  loss is 2.306025505065918, learning rate is 0.01 .....
# 共用时:  89.82822060585022
# iteration: 17000 / 30000;  loss is 2.319121837615967, learning rate is 0.01 .....
# 共用时:  92.53269243240356
# iteration: 17500 / 30000;  loss is 2.3078174591064453, learning rate is 0.01 .....
# 共用时:  95.34484100341797
# iteration: 18000 / 30000;  loss is 2.3265573978424072, learning rate is 0.01 .....
# 共用时:  98.08588457107544
# iteration: 18500 / 30000;  loss is 2.307291030883789, learning rate is 0.01 .....
# 共用时:  100.79787278175354
# iteration: 19000 / 30000;  loss is 2.3000621795654297, learning rate is 0.01 .....
# 共用时:  103.32247805595398
# iteration: 19500 / 30000;  loss is 2.3973851203918457, learning rate is 0.01 .....
# 共用时:  106.0721755027771
# iteration: 20000 / 30000;  loss is 2.3100693225860596, learning rate is 0.01 .....
# 共用时:  108.77419471740723
# iteration: 20500 / 30000;  loss is 2.3262643814086914, learning rate is 0.01 .....
# 共用时:  111.4411084651947
# iteration: 21000 / 30000;  loss is 2.300187349319458, learning rate is 0.01 .....
# 共用时:  114.09797358512878
# iteration: 21500 / 30000;  loss is 2.285522222518921, learning rate is 0.01 .....
# 共用时:  116.85159802436829
# iteration: 22000 / 30000;  loss is 2.313711643218994, learning rate is 0.01 .....
# 共用时:  119.48798561096191
# iteration: 22500 / 30000;  loss is 2.277007818222046, learning rate is 0.01 .....
# 共用时:  122.16862297058105
# iteration: 23000 / 30000;  loss is 2.301926374435425, learning rate is 0.01 .....
# 共用时:  124.85035753250122
# iteration: 23500 / 30000;  loss is 2.3203046321868896, learning rate is 0.01 .....
# 共用时:  127.68205523490906
# iteration: 24000 / 30000;  loss is 2.301612138748169, learning rate is 0.01 .....
# 共用时:  130.3424482345581
# iteration: 24500 / 30000;  loss is 2.296335458755493, learning rate is 0.01 .....
# 共用时:  133.01449251174927
# iteration: 25000 / 30000;  loss is 2.304039239883423, learning rate is 0.01 .....
# 共用时:  135.70233845710754
# iteration: 25500 / 30000;  loss is 2.3126769065856934, learning rate is 0.01 .....
# 共用时:  138.29007768630981
# iteration: 26000 / 30000;  loss is 2.320535659790039, learning rate is 0.01 .....
# 共用时:  141.01960706710815
# iteration: 26500 / 30000;  loss is 2.3104772567749023, learning rate is 0.01 .....
# 共用时:  143.79921317100525
# iteration: 27000 / 30000;  loss is 2.3053770065307617, learning rate is 0.01 .....
# 共用时:  146.46424460411072
# iteration: 27500 / 30000;  loss is 2.313209295272827, learning rate is 0.01 .....
# 共用时:  149.20934557914734
# iteration: 28000 / 30000;  loss is 2.327350378036499, learning rate is 0.01 .....
# 共用时:  151.86461567878723
# iteration: 28500 / 30000;  loss is 2.321108818054199, learning rate is 0.01 .....
# 共用时:  154.49403357505798
# iteration: 29000 / 30000;  loss is 2.3153488636016846, learning rate is 0.01 .....
# 共用时:  157.14379382133484
# iteration: 29500 / 30000;  loss is 2.3302154541015625, learning rate is 0.01 .....
# 共用时:  159.82602524757385
# training is end
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# ?tf.truncated_normal_initializer

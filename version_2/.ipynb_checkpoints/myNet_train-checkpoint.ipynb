# %%
import tensorflow as tf
import numpy as np
import Ipynb_importer
import myNet_infer_1
# Out:
# importing Jupyter notebook from myNet_infer.ipynb

# %%
BATCH_SIZE = 100

NUM_EPOCH = 30000 #迭代次数、
LEARNING_RATE = 0.01  # larning rate
def train_model(mnist):

    x = tf.placeholder(dtype=tf.float32, shape=[BATCH_SIZE, 28, 28, 1],name="input")
    y_predicted = myNet_infer_1.LeNet_inference(x)
    y_label = tf.placeholder(dtype=tf.float32, shape=[BATCH_SIZE, 10], name="label")

    """
    loss function and optimization 

    """
    #result = tf.multiply(y_predicted, 1, name="infer")
    loss_all = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_label, logits=y_predicted)
    loss = tf.reduce_mean(loss_all)
    train_op = tf.train.GradientDescentOptimizer(LEARNING_RATE).minimize(loss)
    
    """设置, tf最大占用显卡内存比例, 并让gpu自主增长所需要内存: 因为tf正常会自动占有所有内存"""
    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.7  # 程序最多只能占用指定gpu50%的显存
    config.gpu_options.allow_growth = True 
    
    loss_list = np.array([])
    import time
    saver = tf.train.Saver()
    with tf.Session(config = config) as sess:
        sess.run(tf.global_variables_initializer())
        start_all = time.time()
        
        for i in range(NUM_EPOCH):
            
            xs,ys = mnist.train.next_batch(batch_size=BATCH_SIZE) #batch gradient descent
            xs.shape = (BATCH_SIZE, 28, 28, 1) #reshape the input 

            _, loss_np = sess.run([train_op, loss], feed_dict={x:xs, y_label:ys})
            
            if i% 500 == 0:
                loss_list = np.append(loss_list,loss_np )
                end = time.time()
                print("iteration: {} / {};  loss is {}, learning rate is {} .....".format(i, NUM_EPOCH,loss_np, LEARNING_RATE))
                print( "共用时: ", end - start_all)
                saver.save(sess, "./model_param_1/model.ckpt",global_step = i)

        print("training is end")
        return

# %%
def read_date():
    from tensorflow.examples.tutorials.mnist import input_data
    mnist = input_data.read_data_sets('./input_data', one_hot=True, validation_size=500)
    return mnist

# %%
def main(argv = None):
    mnist = read_date()
    train_model(mnist)

if __name__ == "__main__":
    tf.app.run()
# Out:
# WARNING:tensorflow:From <ipython-input-4-c6b80f814b4d>:3: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./input_data\train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./input_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ./input_data\t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ./input_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# iteration: 0 / 30000;  loss is 6.071120738983154, learning rate is 0.01 .....
# 共用时:  1.0986902713775635
# iteration: 500 / 30000;  loss is 0.19019895792007446, learning rate is 0.01 .....
# 共用时:  3.749845504760742
# iteration: 1000 / 30000;  loss is 0.1761273741722107, learning rate is 0.01 .....
# 共用时:  6.445691823959351
# iteration: 1500 / 30000;  loss is 0.07716397941112518, learning rate is 0.01 .....
# 共用时:  9.17076301574707
# iteration: 2000 / 30000;  loss is 0.08390311896800995, learning rate is 0.01 .....
# 共用时:  11.961929321289062
# iteration: 2500 / 30000;  loss is 0.035273853689432144, learning rate is 0.01 .....
# 共用时:  14.58065152168274
# iteration: 3000 / 30000;  loss is 0.0628407821059227, learning rate is 0.01 .....
# 共用时:  17.208923816680908
# iteration: 3500 / 30000;  loss is 0.042466629296541214, learning rate is 0.01 .....
# 共用时:  19.833419799804688
# iteration: 4000 / 30000;  loss is 0.04193897545337677, learning rate is 0.01 .....
# 共用时:  22.48788070678711
# iteration: 4500 / 30000;  loss is 0.011754238978028297, learning rate is 0.01 .....
# 共用时:  25.209871768951416
# iteration: 5000 / 30000;  loss is 0.023299574851989746, learning rate is 0.01 .....
# 共用时:  27.90013861656189
# iteration: 5500 / 30000;  loss is 0.020457811653614044, learning rate is 0.01 .....
# 共用时:  30.563798904418945
# iteration: 6000 / 30000;  loss is 0.028667693957686424, learning rate is 0.01 .....
# 共用时:  33.2107572555542
# iteration: 6500 / 30000;  loss is 0.032964859157800674, learning rate is 0.01 .....
# 共用时:  35.7834689617157
# iteration: 7000 / 30000;  loss is 0.05264551192522049, learning rate is 0.01 .....
# 共用时:  38.424302101135254
# iteration: 7500 / 30000;  loss is 0.05933039262890816, learning rate is 0.01 .....
# 共用时:  41.055899143218994
# iteration: 8000 / 30000;  loss is 0.023232780396938324, learning rate is 0.01 .....
# 共用时:  43.73089957237244
# iteration: 8500 / 30000;  loss is 0.07254160195589066, learning rate is 0.01 .....
# 共用时:  46.393762826919556
# iteration: 9000 / 30000;  loss is 0.04700065031647682, learning rate is 0.01 .....
# 共用时:  49.11433529853821
# iteration: 9500 / 30000;  loss is 0.015653900802135468, learning rate is 0.01 .....
# 共用时:  51.7549614906311
# iteration: 10000 / 30000;  loss is 0.01862235553562641, learning rate is 0.01 .....
# 共用时:  54.473663568496704
# iteration: 10500 / 30000;  loss is 0.03655140474438667, learning rate is 0.01 .....
# 共用时:  57.08919095993042
# iteration: 11000 / 30000;  loss is 0.039381276816129684, learning rate is 0.01 .....
# 共用时:  59.78024458885193
# iteration: 11500 / 30000;  loss is 0.04680708795785904, learning rate is 0.01 .....
# 共用时:  62.4512414932251
# iteration: 12000 / 30000;  loss is 0.010875692591071129, learning rate is 0.01 .....
# 共用时:  65.16861772537231
# iteration: 12500 / 30000;  loss is 0.06285689026117325, learning rate is 0.01 .....
# 共用时:  67.78409242630005
# iteration: 13000 / 30000;  loss is 0.04835212230682373, learning rate is 0.01 .....
# 共用时:  70.3695158958435
# iteration: 13500 / 30000;  loss is 0.008213265798985958, learning rate is 0.01 .....
# 共用时:  73.0658688545227
# iteration: 14000 / 30000;  loss is 0.007720798719674349, learning rate is 0.01 .....
# 共用时:  75.66864728927612
# iteration: 14500 / 30000;  loss is 0.016580428928136826, learning rate is 0.01 .....
# 共用时:  78.33637714385986
# iteration: 15000 / 30000;  loss is 0.011815394274890423, learning rate is 0.01 .....
# 共用时:  81.10337734222412
# iteration: 15500 / 30000;  loss is 0.006266660522669554, learning rate is 0.01 .....
# 共用时:  83.76574635505676
# iteration: 16000 / 30000;  loss is 0.004235041327774525, learning rate is 0.01 .....
# 共用时:  86.42534923553467
# iteration: 16500 / 30000;  loss is 0.0062516178004443645, learning rate is 0.01 .....
# 共用时:  89.00995469093323
# iteration: 17000 / 30000;  loss is 0.027822526171803474, learning rate is 0.01 .....
# 共用时:  91.64440631866455
# iteration: 17500 / 30000;  loss is 0.011143055744469166, learning rate is 0.01 .....
# 共用时:  94.36553812026978
# iteration: 18000 / 30000;  loss is 0.013264927081763744, learning rate is 0.01 .....
# 共用时:  96.95930242538452
# iteration: 18500 / 30000;  loss is 0.002020449610427022, learning rate is 0.01 .....
# 共用时:  99.55053377151489
# iteration: 19000 / 30000;  loss is 0.000919200130738318, learning rate is 0.01 .....
# 共用时:  102.15352010726929
# iteration: 19500 / 30000;  loss is 0.023660702630877495, learning rate is 0.01 .....
# 共用时:  104.88762664794922
# iteration: 20000 / 30000;  loss is 0.008645851165056229, learning rate is 0.01 .....
# 共用时:  107.55584764480591
# iteration: 20500 / 30000;  loss is 0.006865316536277533, learning rate is 0.01 .....
# 共用时:  110.26646709442139
# iteration: 21000 / 30000;  loss is 0.0036057038232684135, learning rate is 0.01 .....
# 共用时:  112.93164038658142
# iteration: 21500 / 30000;  loss is 0.005685470532625914, learning rate is 0.01 .....
# 共用时:  115.69523692131042
# iteration: 22000 / 30000;  loss is 0.003792908973991871, learning rate is 0.01 .....
# 共用时:  118.30311322212219
# iteration: 22500 / 30000;  loss is 0.01303776167333126, learning rate is 0.01 .....
# 共用时:  120.94479632377625
# iteration: 23000 / 30000;  loss is 0.002718518953770399, learning rate is 0.01 .....
# 共用时:  123.57004046440125
# iteration: 23500 / 30000;  loss is 0.0049047996290028095, learning rate is 0.01 .....
# 共用时:  126.35981011390686
# iteration: 24000 / 30000;  loss is 0.0018301940290257335, learning rate is 0.01 .....
# 共用时:  129.02360463142395
# iteration: 24500 / 30000;  loss is 0.0016595222987234592, learning rate is 0.01 .....
# 共用时:  131.71129775047302
# iteration: 25000 / 30000;  loss is 0.001397879677824676, learning rate is 0.01 .....
# 共用时:  134.39580154418945
# iteration: 25500 / 30000;  loss is 0.0012593199498951435, learning rate is 0.01 .....
# 共用时:  137.0338020324707
# iteration: 26000 / 30000;  loss is 0.0025203239638358355, learning rate is 0.01 .....
# 共用时:  139.74990487098694
# iteration: 26500 / 30000;  loss is 0.011635024100542068, learning rate is 0.01 .....
# 共用时:  142.41779565811157
# iteration: 27000 / 30000;  loss is 0.0020852256566286087, learning rate is 0.01 .....
# 共用时:  145.1406853199005
# iteration: 27500 / 30000;  loss is 0.0018290836596861482, learning rate is 0.01 .....
# 共用时:  147.75923538208008
# iteration: 28000 / 30000;  loss is 0.004608881659805775, learning rate is 0.01 .....
# 共用时:  150.4770827293396
# iteration: 28500 / 30000;  loss is 0.0007127968710847199, learning rate is 0.01 .....
# 共用时:  153.12509274482727
# iteration: 29000 / 30000;  loss is 0.0019359959987923503, learning rate is 0.01 .....
# 共用时:  155.750070810318
# iteration: 29500 / 30000;  loss is 0.0014247649814933538, learning rate is 0.01 .....
# 共用时:  158.42494297027588
# training is end
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-4-b22ba57da8a8> in <module>()
#       4
#       5 if __name__ == "__main__":
# ----> 6     tf.app.run()
#
# G:\Anaconda\installCatalog\envs\tensorflow_gpu\lib\site-packages\tensorflow\python\platform\app.py in run(main, argv)
#     123   # Call the main function, passing through any arguments
#     124   # to the final program.
# --> 125   _sys.exit(main(argv))
#     126
#
# SystemExit:
